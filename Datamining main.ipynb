# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preprocessing

# %%
df = pd.read_csv('covid_data.csv')
x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
df.head(10) #prints out the first 10 values of the dataset
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
# 5      2             1    1             2  9999-99-99        2          1
# 6      2             1    1             1  9999-99-99       97          2
# 7      2             1    1             1  9999-99-99       97          1
# 8      2             1    1             2  9999-99-99        2          2
# 9      2             1    1             2  9999-99-99        2          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %%
df.tail(10) #prints out the last 10 values of the dataset
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 1048565      1            13    1             1  9999-99-99       97
# 1048566      2            13    2             1  9999-99-99       97
# 1048567      1            13    1             2  9999-99-99        2
# 1048568      1            13    2             1  9999-99-99       97
# 1048569      1            13    1             2  9999-99-99        2
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 1048565          2   39         2         2  ...       2        2
# 1048566          2   24        97         2  ...       1        2
# ...

# %%
df.info() #gives the details of all the columns and its null value count
df.shape #gives the number of rows and columns in the datset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %%
df.nunique() #categorical data
# Out:
# USMER                     2
# MEDICAL_UNIT             13
# SEX                       2
# PATIENT_TYPE              2
# DATE_DIED               401
# INTUBED                   4
# PNEUMONIA                 3
# AGE                     121
# PREGNANT                  4
# DIABETES                  3
# COPD                      3
# ASTHMA                    3
# INMSUPR                   3
# HIPERTENSION              3
# OTHER_DISEASE             3
# CARDIOVASCULAR            3
# OBESITY                   3
# RENAL_CHRONIC             3
# TOBACCO                   3
# CLASIFFICATION_FINAL      7
# ICU                       4
# dtype: int64

# %%
df.isnull().sum() #there are no null values but in the description of the dataset the null values are labeled as 97,98,99
                    #hence we need to remove these values
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
perc=[]
for col in list(df.columns):
   perc.append(round(len(df[(df[col]==97)| (df[col]==98) | (df[col]==98)])/len(df)*100,2))
#defines an empty list called perc. It then iterates through the columns in the dataframe df. For each column, 
#it calculates the percentage of rows in which the value in the column is 97, 98, or 99, and appends this 
#percentage to the perc list. Finally, it rounds the percentage to two decimal places before appending it to the list.
((pd.DataFrame([df.columns,perc]).T).rename(columns={0:"Feature",1:"Percentage"})).sort_values(by="Percentage")
#the results are shown in tablular form
# Out:
#                  Feature Percentage
# 0                  USMER        0.0
# 1           MEDICAL_UNIT        0.0
# 2                    SEX        0.0
# 3           PATIENT_TYPE        0.0
# 4              DATE_DIED        0.0
# 6              PNEUMONIA        0.0
# 19  CLASIFFICATION_FINAL        0.0
# 7                    AGE       0.02
# 11                ASTHMA       0.28
# 17         RENAL_CHRONIC       0.29
# 16               OBESITY       0.29
# 15        CARDIOVASCULAR       0.29
# 10                  COPD       0.29
# 13          HIPERTENSION        0.3
# 18               TOBACCO       0.31
# 9               DIABETES       0.32
# 12               INMSUPR       0.32
# 14         OTHER_DISEASE       0.48
# 8               PREGNANT      50.28
# 5                INTUBED      80.92
# 20                   ICU      80.92

# %%
df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
#remove columns ICU,Intubed and Pregnant as they have very high null values

# %%
df = df.drop(columns=["ICU", "PREGNANT","INTUBED"])

# %%
df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED',
#        'PNEUMONIA', 'AGE', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL'],
#       dtype='object')

# %%
df = df.replace({97: np.nan, 98: np.nan, 99: np.nan})g

# %%
percent=[]
for col in list(df.columns):
   percent.append(round(len(df[(df[col]==97)| (df[col]==98) | (df[col]==99)])/len(df)*100,2))

((pd.DataFrame([df.columns,percent]).T).rename(columns={0:"Feature",1:"Percentage"})).sort_values(by="Percentage")
# Out:
#                  Feature Percentage
# 0                  USMER        0.0
# 15         RENAL_CHRONIC        0.0
# 14               OBESITY        0.0
# 13        CARDIOVASCULAR        0.0
# 12         OTHER_DISEASE        0.0
# 11          HIPERTENSION        0.0
# 10               INMSUPR        0.0
# 9                 ASTHMA        0.0
# 8                   COPD        0.0
# 7               DIABETES        0.0
# 6                    AGE        0.0
# 5              PNEUMONIA        0.0
# 4              DATE_DIED        0.0
# 3           PATIENT_TYPE        0.0
# 2                    SEX        0.0
# 1           MEDICAL_UNIT        0.0
# 16               TOBACCO        0.0
# 17  CLASIFFICATION_FINAL        0.0

# %%
#we have changed all the values that were 97,98,99 into nan values

# %%
df.isnull().sum() #gives the count of the nan values that are present in each column 
df.shape
# Out:
# (1048575, 18)

# %%
df.dropna(axis = 0,inplace = True)
df.shape
# Out:
# (1024829, 18)

# %%
#number of rows rows is reduced from 1048575 to 1024829

# %%
df.isnull().sum() # all the nan values have been removed
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# PNEUMONIA               0
# AGE                     0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# dtype: int64

# %%
#we need to change all the dates 9999-99-99 to one class and others died date to another class

# %%
#we are representing the people who havent died as 0
#and people wo died because of covid as 1

# %%
df.loc[df.DATE_DIED == "9999-99-99","DATE_DIED"] = 0
print(df.DATE_DIED)
# Out:
# 0          03/05/2020
# 1          03/06/2020
# 2          09/06/2020
# 3          12/06/2020
# 4          21/06/2020
#               ...
# 1048570             0
# 1048571             0
# 1048572             0
# 1048573             0
# 1048574             0
# Name: DATE_DIED, Length: 1024829, dtype: object

# %%
df.loc[df.DATE_DIED != 0,"DATE_DIED"] = 1

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE DATE_DIED  PNEUMONIA   AGE  \
# 0            2             1    1             1         1        1.0  65.0
# 1            2             1    2             1         1        1.0  72.0
# 2            2             1    2             2         1        2.0  55.0
# 3            2             1    1             1         1        2.0  53.0
# 4            2             1    2             1         1        2.0  68.0
# ...        ...           ...  ...           ...       ...        ...   ...
# 1048570      2            13    2             1         0        2.0  40.0
# 1048571      1            13    2             2         0        2.0  51.0
# 1048572      2            13    2             1         0        2.0  55.0
# 1048573      2            13    2             1         0        2.0  28.0
# 1048574      2            13    2             1         0        2.0  52.0
#
# ...

# %%
percentage = df['DATE_DIED'].value_counts().apply(lambda x: x / len(df))
print(percentage*100)
# Out:
# 0    92.719566
# 1     7.280434
# Name: DATE_DIED, dtype: float64

# %%
#percent of people died due to covid is

# %%
df.nunique() #categorical data
# Out:
# USMER                     2
# MEDICAL_UNIT             13
# SEX                       2
# PATIENT_TYPE              2
# DATE_DIED                 2
# PNEUMONIA                 2
# AGE                     118
# DIABETES                  2
# COPD                      2
# ASTHMA                    2
# INMSUPR                   2
# HIPERTENSION              2
# OTHER_DISEASE             2
# CARDIOVASCULAR            2
# OBESITY                   2
# RENAL_CHRONIC             2
# TOBACCO                   2
# CLASIFFICATION_FINAL      7
# dtype: int64

# %%
#we can see that all the columns comtains only 2 classes except age medical unit and classification final

# %%
column = df['AGE']

# Create the bins using the 'cut' function
bins = pd.cut(column, 4, labels=["Young","Middle Aged","Elder","Old"])

# Add the bins to the dataframe
df['AGE'] = bins

# Display the resulting dataframe
print(df)
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE DATE_DIED  PNEUMONIA  \
# 0            2             1    1             1         1        1.0
# 1            2             1    2             1         1        1.0
# 2            2             1    2             2         1        2.0
# 3            2             1    1             1         1        2.0
# 4            2             1    2             1         1        2.0
# ...        ...           ...  ...           ...       ...        ...
# 1048570      2            13    2             1         0        2.0
# 1048571      1            13    2             2         0        2.0
# 1048572      2            13    2             1         0        2.0
# 1048573      2            13    2             1         0        2.0
# 1048574      2            13    2             1         0        2.0
#
#                  AGE  DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  \
# 0              Elder       2.0   2.0     2.0      2.0           1.0
# ...

# %%
df.nunique() #converted into 4 classes
# Out:
# USMER                    2
# MEDICAL_UNIT            13
# SEX                      2
# PATIENT_TYPE             2
# DATE_DIED                2
# PNEUMONIA                2
# AGE                      4
# DIABETES                 2
# COPD                     2
# ASTHMA                   2
# INMSUPR                  2
# HIPERTENSION             2
# OTHER_DISEASE            2
# CARDIOVASCULAR           2
# OBESITY                  2
# RENAL_CHRONIC            2
# TOBACCO                  2
# CLASIFFICATION_FINAL     7
# dtype: int64

# %%
categ_cols = ['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'PNEUMONIA',
        'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR', 'HIPERTENSION',
       'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY', 'RENAL_CHRONIC',
       'TOBACCO', 'CLASIFFICATION_FINAL','AGE_Young','AGE_Middle Aged','AGE_Elder','AGE_Old']

# %% [markdown]
# In the given dataset the boolean feature 1 represents Yes and 2 represents No
# sex - 1(women) 2(men)
# age - classified into 4 parts and made into separate columns
# for date died 0 means the person is not dead and 1 means the person died due to covid
# patient type - 1 means the person was not hospitalized and 2 means he was hospitalized
# immunosupressed -  (Having a weakened immune system) so 1 is immunosupressed and 2 is not
# medical unit - type of institution of the patient treated medical units of the first,second or higher unit
# intubed - weather patient was connected to the ventilator

# %%
import seaborn as sns
for col in categ_cols:
    plt.figure(figsize=(15,10))
    sns.countplot(x=df[col],hue=df["DATE_DIED"])

# %% [markdown]
# # Observations made

# %%
#Number of male died is more than the number of female died
#Death more in patient type- Hospitalization
#Death cases more in Age between 40-100.

# %%
categories, counts = np.unique(df['CLASIFFICATION_FINAL'], return_counts=True)

# Create the pie chart
fig1, ax1 = plt.subplots()
ax1.pie(counts, labels=categories, autopct='%1.1f%%', shadow=True, startangle=90)
ax1.axis('equal')

plt.show()

# %%
df=pd.get_dummies(data=df,columns=["AGE"])
# converting the categorical data into numeric this converts the data into numeric by using one hot encoder
#one hot encoder basically converts all the diff classes into different columns with values 0 and 1
#0 specifies that class is not presnt and 1 specifies that the class is present

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE DATE_DIED  PNEUMONIA  \
# 0            2             1    1             1         1        1.0
# 1            2             1    2             1         1        1.0
# 2            2             1    2             2         1        2.0
# 3            2             1    1             1         1        2.0
# 4            2             1    2             1         1        2.0
# ...        ...           ...  ...           ...       ...        ...
# 1048570      2            13    2             1         0        2.0
# 1048571      1            13    2             2         0        2.0
# 1048572      2            13    2             1         0        2.0
# 1048573      2            13    2             1         0        2.0
# 1048574      2            13    2             1         0        2.0
#
#          DIABETES  COPD  ASTHMA  INMSUPR  ...  OTHER_DISEASE  CARDIOVASCULAR  \
# ...

# %% [markdown]
# # Scaling the Data

# %%
x = df.drop(["DATE_DIED"],axis=1)
y = df["DATE_DIED"].astype(int)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# # Knn

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[230802   6689]
#  [ 10645   8072]]
# 0.9323440329732092

# %% [markdown]
# # Decision Tree Implementation

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[232104   5387]
#  [ 10586   8131]]
# 0.9376561231499406

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
score = []

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[231991   5500]
#  [ 10350   8367]]
# 0.9381362018360082

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[233583   3908]
#  [ 12051   6666]]
# 0.9377107662524199

# %% [markdown]
# # Comparisions of all the Models

# %%
knn_acc = 0.9377107662524199
dctree_acc = 0.9376561231499406
forest_acc = 0.9381362018360082
svm_acc = 0.9377107662524199

# %%
pd.DataFrame({"Model":["KNN","Decision Tree","Random Forest","SVM"],
             "Accuracy":[knn_acc,dctree_acc,forest_acc,svm_acc]})
# Out:
#            Model  Accuracy
# 0            KNN  0.937711
# 1  Decision Tree  0.937656
# 2  Random Forest  0.938136
# 3            SVM  0.937711

# %%
#print(classifier.predict(sc.transform([[30,87000]])))
